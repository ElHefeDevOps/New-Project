# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# import requests 
import scipy.stats as st
import time
from scipy.stats import linregress

import datetime
d = datetime.datetime.today()
date = f'{d.month}-{d.day}-{d.year}'

# from covid19_data import JHU

# Import API key
# from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
# from citipy import citipy

# %%
df = pd.read_csv('time-series-19-covid-combined.csv')

# %%
df
# Out:
#               Date Country/Region Province/State  Confirmed  Recovered  Deaths
# 0       2020-01-22    Afghanistan            NaN          0        0.0       0
# 1       2020-01-23    Afghanistan            NaN          0        0.0       0
# 2       2020-01-24    Afghanistan            NaN          0        0.0       0
# 3       2020-01-25    Afghanistan            NaN          0        0.0       0
# 4       2020-01-26    Afghanistan            NaN          0        0.0       0
# ...            ...            ...            ...        ...        ...     ...
# 105646  2021-02-07       Zimbabwe            NaN      34552    28551.0    1326
# 105647  2021-02-08       Zimbabwe            NaN      34658    28825.0    1339
# 105648  2021-02-09       Zimbabwe            NaN      34781    29289.0    1353
# 105649  2021-02-10       Zimbabwe            NaN      34864    29471.0    1364
# 105650  2021-02-11       Zimbabwe            NaN      34864    29471.0    1364
#
# [105651 rows x 6 columns]

# %%
date = []
country = []
Province = []
Confirmed = []
Deaths = []
Recovered = []

country_list = []

counter = 0

print('Beginning Data Retrieval')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
covid_df = pd.DataFrame({
    'Recovered': recovered,
    'Deaths': deaths,
    'Confirmed': confirmed,
    'Country': country
    
})

display(covid_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-88875a06dd99> in <module>
#       1 covid_df = pd.DataFrame({
# ----> 2     'Recovered': recovered,
#       3     'Deaths': deaths,
#       4     'Confirmed': confirmed,
#       5     'Country': country
#
# NameError: name 'recovered' is not defined

# %%
x = df['Country/Reigon']
y = df['Confirmed']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.bar(x, y, c=y, cmap='Greens', edgecolor='gray')

# #Assign labels, title, and grid
# plt.xlabel('Country')
# plt.ylabel('Total Confirmed')

# # Title calls on the import datetime dependency to populate current day
# plt.title(f'Country vs Confirmed Cases ({date})')
# plt.grid()

# # Save plot as png file in output folder
# plt.savefig('Confirmed.png')

# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country/Reigon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-1ba21520fd25> in <module>
# ----> 1 x = df['Country/Reigon']
#       2 y = df['Confirmed']
#       3
#       4 # Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
#       5 plt.bar(x, y, c=y, cmap='Greens', edgecolor='gray')
#
# ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country/Reigon'
